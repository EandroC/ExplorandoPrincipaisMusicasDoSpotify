# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %% [markdown]
# ## Guia do CSV
#
# - id: O ID do Spotify é um identificador único para a faixa, usado dentro da plataforma do Spotify para referência e recuperação fácil da música.
#
# - artist_names: Esta coluna contém o nome ou nomes do artista ou artistas que criaram a faixa. Ajuda a identificar os criadores da música.
#
# - track_name: O nome da faixa, que serve como seu título. É como a faixa é comumente referida e reconhecida.
#
# - source: A fonte refere-se ao nome da gravadora que lançou a faixa. Ajuda a identificar a entidade responsável pela distribuição da música.
#
# - key: A chave da faixa refere-se à tonalidade musical na qual a música é composta. Indica o centro tonal ou altura em torno do qual a melodia e a harmonia giram.
#
# - mode: O modo indica se a faixa está em uma tonalidade maior ou menor, fornecendo insights sobre o humor geral ou a qualidade emocional da música.
#
# - time_signature: A assinatura de tempo é uma convenção notacional usada em partituras para indicar o número de batidas em cada compasso e o tipo de nota que recebe uma batida. Ajuda os músicos a interpretar o ritmo da faixa.
#
# - danceability: Descreve o quão adequada uma faixa é para dançar com base em vários elementos musicais, como tempo, estabilidade rítmica, força do ritmo e regularidade geral. Varia de 0.0 (menos dançável) a 1.0 (mais dançável).
#
# - energy: É uma medida perceptual de intensidade e atividade dentro de uma faixa, variando de 0.0 a 1.0. Reflete qualidades como tempo, volume e instrumentação que contribuem para a excitação ou vigor geral da música.
#
# - speechiness: Detecta a presença de palavras faladas em uma faixa, distinguindo entre música puramente instrumental e faixas contendo elementos vocais, como canto ou fala. Varia de 0.0 (música) a 1.0 (apenas palavras faladas).
#
# - acousticness: Medida que varia de 0.0 a 1.0 e indica a probabilidade de uma faixa ser acústica, com valores mais altos sugerindo uma proporção maior de instrumentação acústica.
#
# - instrumentalness: Prevê se uma faixa contém vocais ou é puramente instrumental. Varia de 0.0 (vocais presentes) a 1.0 (sem vocais), com valores mais altos indicando uma maior probabilidade de música instrumental.
#
# - liveness: A vivacidade detecta a presença de uma plateia em uma gravação, com valores mais altos indicando uma maior probabilidade de a faixa ter sido executada ao vivo em vez de em um estúdio.
#
# - valence: A valência mede a positividade musical transmitida por uma faixa, variando de 0.0 (negativa) a 1.0 (positiva). Reflete o conteúdo emocional da música, com valores mais altos indicando um humor mais positivo.
#
# - loudness: O volume mede o volume geral de uma faixa em decibéis (dB), fornecendo informações sobre sua intensidade ou amplitude percebida. Influencia a percepção de "volume" ou "suavidade" da música.
#
# - tempo: O tempo refere-se à velocidade geral ou ao ritmo de uma faixa, medido em batidas por minuto (BPM). Indica o quão rápido ou lento a música soa e influencia seu caráter rítmico.
#
# - duration_ms: A duração da faixa em milissegundos (ms), representando o tempo total desde o início até o fim da música.
#
# - weeks_on_chart: O número de semanas que a faixa passou nas paradas das 200 melhores, indicando sua popularidade e longevidade em termos de desempenho nas paradas.
#
# - streams: O número de vezes que a faixa foi reproduzida durante seu período nas paradas, fornecendo insights sobre sua popularidade e engajamento dos ouvintes.

# %% [markdown]
# ## Analisando colunas e dados

# %%
dados = pd.read_csv('spotify_top_songs_audio_features.csv', sep=',')

dados.head()
# Out:
#                        id                artist_names  \
# 0  000xQL6tZNLJzIrtIgxqSl         ZAYN, PARTYNEXTDOOR
# 1  003eoIwxETJujVWmNFMoZy                Alessia Cara
# 2  003vvx7Niy0yvhvHt4a68B                 The Killers
# 3  00B7TZ0Xawar6NZ00JFomN  Cardi B, Chance the Rapper
# 4  00Blm7zeNqgYLPtW6zg8cj     Post Malone, The Weeknd
#
#                              track_name              source    key   mode  \
# 0  Still Got Time (feat. PARTYNEXTDOOR)   RCA Records Label      G  Major
# 1                         Growing Pains  Def Jam Recordings  C#/Db  Minor
# 2                        Mr. Brightside      Island Records  C#/Db  Major
# 3   Best Life (feat. Chance The Rapper)        Atlantic/KSR      A  Major
# 4       One Right Now (with The Weeknd)    Republic Records  C#/Db  Major
#
#   time_signature  danceability  energy  speechiness  acousticness  \
# 0        4 beats         0.748   0.627       0.0639       0.13100
# ...

# %%
dados.shape
# Out:
# (6513, 19)

# %%
dados.dtypes
# Out:
# id                   object
# artist_names         object
# track_name           object
# source               object
# key                  object
# mode                 object
# time_signature       object
# danceability        float64
# energy              float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# loudness            float64
# tempo               float64
# duration_ms           int64
# weeks_on_chart        int64
# streams               int64
# dtype: object

# %% [markdown]
# ### Removendo coluna 'id',  pois não achei utilidade para ela por enquanto

# %%
dados = dados.drop('id', axis=1)

# %% [markdown]
# ## Divisão proposta
# ### Artistas, faixas e descrições:
# - artist_names
# - track_name
# - source
# - key
# - mode
# - time_signature
#
# ### Atributos Musicais:
# - danceability
# - energy
# - speechiness
# - acousticness
# - instrumentalness
# - liveness
# - valence
# - loudness
# - tempo
# - duration_ms
#
# ### Popularidade e Desempenho:
# - weeks_on_chart
# - streams

# %% [markdown]
# ## Artistas, faixas e descrições:

# %% [markdown]
# ### Quantidade de aparições de um artista no top200, incluindo participações

# %%
# Divide a string em artistas individuais e conta as ocorrências
artistas = dados['artist_names'].str.split(', ').explode().value_counts().reset_index()

# Renomeia as colunas
artistas.columns = ['Artista', 'QuantidadeAparicoes']

# Imprime o DataFrame resultante
artistas.head(50)
# Out:
#              Artista  QuantidadeAparicoes
# 0              Drake                  229
# 1       Taylor Swift                  203
# 2          Bad Bunny                  159
# 3       Travis Scott                  127
# 4        Post Malone                  111
# 5         Juice WRLD                  110
# 6         The Weeknd                  104
# 7      Ariana Grande                  101
# 8          21 Savage                   97
# 9                BTS                   95
# 10          J Balvin                   90
# 11        Kanye West                   89
# 12        Ed Sheeran                   84
# 13      Lil Uzi Vert                   83
# 14            Future                   81
# 15     Justin Bieber                   78
# 16             Ozuna                   76
# 17            Eminem                   75
# 18          Lil Baby                   67
# 19       Nicki Minaj                   62
# 20          Anuel AA                   62
# ...

# %% [markdown]
# ### Analisando se foi utilizado algum outro simbolo para dividir dois artitas além da virgula

# %%
padrao = r'[^a-zA-Z0-9\s]'

# Lista para armazenar os artistas que atendem ao critério
artistas_analisar = []

# Iterar sobre as linhas do DataFrame e adicionar os artistas que atendem ao critério à lista
for index, row in artistas.iterrows():
    artista = row['Artista']
    # Verificar se o nome do artista contém caracteres que não são letras nem números
    if re.search(padrao, artista):
        artistas_analisar.append(artista)

# Criar um novo DataFrame com os artistas que atendem ao critério
artistas_analisar = pd.DataFrame({'Artista': artistas_analisar})

artistas_analisar.head(50)
# Out:
#                    Artista
# 0                  J. Cole
# 1            Ty Dolla $ign
# 2                  Beyoncé
# 3               A$AP Rocky
# 4                  ROSALÍA
# 5               Anne-Marie
# 6            Lenny Tavárez
# 7           Anderson .Paak
# 8                   G-Eazy
# 9                       ¥$
# 10           Zion & Lennox
# 11                  Tiësto
# 12                Arcángel
# 13                    P!nk
# 14     Panic! At The Disco
# 15           Michael Bublé
# 16        Marília Mendonça
# 17                Måneskin
# 18                   JAY-Z
# 19             Luísa Sonza
# 20      Axwell /\ Ingrosso
# 21               Zé Felipe
# 22              C. Tangana
# 23     Zé Neto & Cristiano
# 24          Wisin & Yandel
# 25                (G)I-DLE
# 26              Rafa Pabön
# 27                  j-hope
# 28                      MØ
# 29       Israel & Rodolffo
# 30              Ñengo Flow
# 31            Jasiel Nuñez
# 32  Os Barões Da Pisadinha
# ...

# %% [markdown]
# ### Analisando musicas que mais apareceram

# %%
musicas = dados[['track_name', 'artist_names']].explode('artist_names').groupby(['track_name', 'artist_names']).size().reset_index(name='Quantidade')

# Renomeia as colunas
musicas.columns = ['musica', 'Artista', 'QuantidadeVezes']
musicas = musicas.sort_values(by='QuantidadeVezes', ascending=False)

# Imprime o DataFrame resultante
musicas.head(50)
# Out:
#                                                  musica  \
# 2324                                   Jingle Bell Rock
# 4155                                        Sleigh Ride
# 3052                           My Only Wish (This Year)
# 557                                            Believer
# 4663                                            Thunder
# 4370      Sunflower - Spider-Man: Into the Spider-Verse
# 5035                                  Whatever It Takes
# 5438                         rockstar (feat. 21 Savage)
# 251                            All The Stars (with SZA)
# 2893                                            Mean It
# 4642                                       This Feeling
# 4943                                         Wake Me Up
# 5328                                   fuck, i'm lonely
# 346                              Astronaut In The Ocean
# 3908                                   SPIT IN MY FACE!
# 3396                                  PAINTING PICTURES
# ...

# %% [markdown]
# ### Aqui temos um problema quanto as musicas

# %%
ocorrencias = dados[dados['track_name'].str.contains('Jingle Bell Rock')]
ocorrencias
# Out:
#                  artist_names                          track_name  \
# 1331              Bobby Helms                    Jingle Bell Rock
# 3108              Bobby Helms                    Jingle Bell Rock
# 3585              Bobby Helms                    Jingle Bell Rock
# 5382              Bobby Helms                    Jingle Bell Rock
# 5661              Bobby Helms                    Jingle Bell Rock
# 5669  Daryl Hall & John Oates  Jingle Bell Rock - Daryl's Version
# 6450              Bobby Helms                    Jingle Bell Rock
#
#                              source key   mode time_signature  danceability  \
# 1331  Universal Digital Enterprises   D  Major        4 beats         0.741
# 3108                         Geffen   D  Major        4 beats         0.754
# 3585  Universal Digital Enterprises   D  Major        4 beats         0.741
# 5382  Universal Digital Enterprises   D  Major        4 beats         0.729
# ...

# %% [markdown]
# Existem musicas que provavelmente que entraram e sairam do spotify e voltaram novamente em algum momento, covers, musicas com nomes iguais mas artistas diferente e musicas com os mesmos artistas mas colunas com informações sonoras diferentes. Preciso me atentar quando for manipular colunas que musicas repetidas possam atrapalhar os resultados.

# %% [markdown]
# ### Listando gravadoras

# %%
# Divide a string em artistas individuais e conta as ocorrências
source = dados['source'].str.split(', ').explode().value_counts().reset_index()

# Renomeia as colunas
source.columns = ['source', 'QuantidadeAparicoes']

# Imprime o DataFrame resultante
source.head(50)
# Out:
#                                                source  QuantidadeAparicoes
# 0                                            Columbia                  317
# 1                                    Republic Records                  271
# 2                                        Taylor Swift                  178
# 3                                                 LLC                  150
# 4                                      Warner Records                  140
# 5                             Rimas Entertainment LLC                  125
# 6                                    Sony Music Latin                  124
# 7                                        BIGHIT MUSIC                  119
# 8                                    Atlantic Records                  110
# 9                                 Atlantic Records UK                  106
# 10                                  RCA Records Label                   91
# ...

# %%
key = dados.groupby(['key']).size()
key
# Out:
# key
# A        524
# A#/Bb    465
# B        567
# C        705
# C#/Db    942
# D        524
# D#/Eb    182
# E        424
# F        531
# F#/Gb    501
# G        595
# G#/Ab    553
# dtype: int64

# %%
mode = dados.groupby(['mode']).size()
mode
# Out:
# mode
# Major    3747
# Minor    2766
# dtype: int64

# %%
time_signature = dados.groupby(['time_signature']).size()
time_signature
# Out:
# time_signature
# 1            25
# 3 beats     324
# 4 beats    6057
# 5 beats     107
# dtype: int64

# %%
dados[dados['time_signature'].str.contains('1')]
# Out:
#                                            artist_names  \
# 362                                            Lil Tjay
# 409                                            Lil Tjay
# 836                                               Adele
# 1194                                          Sam Smith
# 1474                                 Bizarrap, Anuel AA
# 1812                                       P!nk, Khalid
# 2335                                          blackbear
# 2426  DJ Khaled, Rick Ross, Lil Wayne, JAY-Z, John L...
# 2834                          Gunna, Future, Young Thug
# 2855                           Eslabon Armado, DannyLux
# 2905                                       Lana Del Rey
# 2979                          Gunna, Future, Young Thug
# 2983                       Fuerza Regida, Edgardo Nuñez
# 3238                                         Tate McRae
# 3453                                       Alexander 23
# 4978                                                SZA
# ...

# %% [markdown]
# ## Atributos Musicais:

# %% [markdown]
# ### Removendo duplicatas, pois acredito que a presença delas pode impactar os resultados das próximas colunas.

# %% [markdown]
# Também estou emovendo colunas sobre semanas no gráfico e quantidade de streams, pois não são relevantes para determinar se uma música é única ou não.

# %%
dados_sem_duplicatas = dados.drop(['weeks_on_chart', 'streams'], axis=1)

duplicatas = dados_sem_duplicatas.duplicated()

dados_sem_duplicatas[duplicatas]
# Out:
#                 artist_names                   track_name  \
# 449            Maroon 5, SZA   What Lovers Do (feat. SZA)
# 490               Kanye West                   Praise God
# 710                     Joji     SLOW DANCING IN THE DARK
# 719               Juice WRLD                 Lucid Dreams
# 767                      BTS                     Dynamite
# ...                      ...                          ...
# 6442                  Hozier         Almost (Sweet Music)
# 6450             Bobby Helms             Jingle Bell Rock
# 6477             Post Malone                         Wow.
# 6481       Kygo, OneRepublic                Lose Somebody
# 6485  Juice WRLD, Marshmello  Come & Go (with Marshmello)
#
#                                       source    key   mode time_signature  \
# 449                      Interscope Records*      F  Minor        4 beats
# 490             Rock The World/IDJ/Kanye LP7  C#/Db  Major        4 beats
# ...

# %%
dados_sem_duplicatas = dados_sem_duplicatas.drop_duplicates()

len(dados_sem_duplicatas)
# Out:
# 6161

# %% [markdown]
# ### Visão geral do atributos musicais das músicas que estão presentes no top 200

# %%
colunas = ['danceability', 'energy', 'speechiness',
           'acousticness', 'liveness', 'valence', 
           'loudness', 'tempo', 'duration_ms']

# Crie uma figura e um conjunto de eixos com 6 subtramas
fig, axs = plt.subplots(3, 3, figsize=(15, 10))

# Flatten the axs array to make it easier to iterate over
axs = axs.flatten()

# Iterar sobre cada coluna especificada e criar um histograma para ela
for i, coluna in enumerate(colunas):
    axs[i].hist(dados_sem_duplicatas[coluna], bins=10, color='blue', edgecolor='black')
    axs[i].set_title(f'Histograma de {coluna}')
    axs[i].set_xlabel('Músicas')
    axs[i].set_ylabel('Frequência')

# Ajustar layout para evitar sobreposição
plt.tight_layout()

# Mostrar os histogramas
plt.show()

# %% [markdown]
# ### Visão por atributo

# %% [markdown]
# #### Danceability

# %%
# Encontrar os valores mínimo, mediano e máximo de 'danceability'
min_value = dados_sem_duplicatas['danceability'].min()
median_value = dados_sem_duplicatas['danceability'].median()
max_value = dados_sem_duplicatas['danceability'].max()

# Encontrar as músicas correspondentes a esses valores
min_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['danceability'] == min_value][['artist_names', 'track_name']].values[0]
median_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['danceability'] == median_value][['artist_names', 'track_name']].values[0]
max_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['danceability'] == max_value][['artist_names', 'track_name']].values[0]

# Criar o histograma
plt.hist(dados_sem_duplicatas['danceability'], bins=10, color='blue', edgecolor='black')

# Adicionar marcadores para os valores mínimo, mediano e máximo
plt.scatter(min_value, 50, color='red', label=f'Menor valor: {min_artist_song[0]} - {min_artist_song[1]}')
plt.scatter(median_value, 50, color='green', label=f'Valor central: {median_artist_song[0]} - {median_artist_song[1]}')
plt.scatter(max_value, 50, color='orange', label=f'Maior valor: {max_artist_song[0]} - {max_artist_song[1]}')

# Adicionar rótulos
plt.xlabel('Danceability')
plt.ylabel('Numero de músicas')
plt.title('Histograma de Danceability')

# Adicionar descrição da dançabilidade abaixo do gráfico com quebras de linha
description = "Danceability descreve o quão adequada uma faixa é para dançar com base em vários elementos musicais,\ncomo tempo,estabilidade rítmica, força do ritmo e regularidade geral.\nVaria de 0.0 (menos dançável) a 1.0 (mais dançável)."
plt.figtext(0.5, -0.05, description, horizontalalignment='center', verticalalignment='center')

# Exibir o histograma
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# #### Energy

# %%
min_value = dados_sem_duplicatas['energy'].min()
median_value = dados_sem_duplicatas['energy'].median()
max_value = dados_sem_duplicatas['energy'].max()

min_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['energy'] == min_value][['artist_names', 'track_name']].values[0]
median_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['energy'] == median_value][['artist_names', 'track_name']].values[0]
max_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['energy'] == max_value][['artist_names', 'track_name']].values[0]

plt.hist(dados_sem_duplicatas['energy'], bins=10, color='blue', edgecolor='black')

plt.scatter(min_value, 50, color='red', label=f'Menor valor: {min_artist_song[0]} - {min_artist_song[1]}')
plt.scatter(median_value, 50, color='green', label=f'Valor central: {median_artist_song[0]} - {median_artist_song[1]}')
plt.scatter(max_value, 50, color='orange', label=f'Maior valor: {max_artist_song[0]} - {max_artist_song[1]}')

plt.xlabel('Energy')
plt.ylabel('Numero de músicas')
plt.title('Histograma de Energy')

description = "É uma medida perceptual de intensidade e atividade dentro de uma faixa,\n variando de 0.0 a 1.0. Reflete qualidades como tempo,\n volume e instrumentação que contribuem para a excitação ou vigor geral da música."
plt.figtext(0.5, -0.05, description, horizontalalignment='center', verticalalignment='center')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# #### Speechiness

# %%
min_value = dados_sem_duplicatas['speechiness'].min()
median_value = dados_sem_duplicatas['speechiness'].median()
max_value = dados_sem_duplicatas['speechiness'].max()

min_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['speechiness'] == min_value][['artist_names', 'track_name']].values[0]
median_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['speechiness'] == median_value][['artist_names', 'track_name']].values[0]
max_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['speechiness'] == max_value][['artist_names', 'track_name']].values[0]

plt.hist(dados_sem_duplicatas['speechiness'], bins=10, color='blue', edgecolor='black')

plt.scatter(min_value, 50, color='red', label=f'Menor valor: {min_artist_song[0]} - {min_artist_song[1]}')
plt.scatter(median_value, 50, color='green', label=f'Valor central: {median_artist_song[0]} - {median_artist_song[1]}')
plt.scatter(max_value, 50, color='orange', label=f'Maior valor: {max_artist_song[0]} - {max_artist_song[1]}')

plt.xlabel('Speechiness')
plt.ylabel('Numero de músicas')
plt.title('Histograma de Speechiness')

description = "Detecta a presença de palavras faladas em uma faixa,\n distinguindo entre música puramente instrumental e faixas contendo elementos vocais, como canto ou fala.\n Varia de 0.0 (música) a 1.0 (apenas palavras faladas)."
plt.figtext(0.5, -0.05, description, horizontalalignment='center', verticalalignment='center')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# #### Acousticness

# %%
min_value = dados_sem_duplicatas['acousticness'].min()
median_value = dados_sem_duplicatas['acousticness'].median()
max_value = dados_sem_duplicatas['acousticness'].max()

min_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['acousticness'] == min_value][['artist_names', 'track_name']].values[0]
median_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['acousticness'] == median_value][['artist_names', 'track_name']].values[0]
max_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['acousticness'] == max_value][['artist_names', 'track_name']].values[0]

plt.hist(dados_sem_duplicatas['acousticness'], bins=10, color='blue', edgecolor='black')

plt.scatter(min_value, 50, color='red', label=f'Menor valor: {min_artist_song[0]} - {min_artist_song[1]}')
plt.scatter(median_value, 50, color='green', label=f'Valor central: {median_artist_song[0]} - {median_artist_song[1]}')
plt.scatter(max_value, 50, color='orange', label=f'Maior valor: {max_artist_song[0]} - {max_artist_song[1]}')

plt.xlabel('Acousticness')
plt.ylabel('Numero de músicas')
plt.title('Histograma de Acousticness')

description = "Medida que varia de 0.0 a 1.0 e indica a probabilidade de uma faixa ser acústica,\n com valores mais altos sugerindo uma proporção maior de instrumentação acústica."
plt.figtext(0.5, -0.05, description, horizontalalignment='center', verticalalignment='center')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# #### Instrumentalness

# %%
min_value = dados_sem_duplicatas['instrumentalness'].min()
median_value = dados_sem_duplicatas['instrumentalness'].median()
max_value = dados_sem_duplicatas['instrumentalness'].max()

min_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['instrumentalness'] == min_value][['artist_names', 'track_name']].values[0]
median_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['instrumentalness'] == median_value][['artist_names', 'track_name']].values[0]
max_artist_song = dados_sem_duplicatas[dados_sem_duplicatas['instrumentalness'] == max_value][['artist_names', 'track_name']].values[0]

plt.hist(dados_sem_duplicatas['instrumentalness'], bins=10, color='blue', edgecolor='black')

plt.scatter(min_value, 50, color='red', label=f'Menor valor: {min_artist_song[0]} - {min_artist_song[1]}')
plt.scatter(median_value, 50, color='green', label=f'Valor central: {median_artist_song[0]} - {median_artist_song[1]}')
plt.scatter(max_value, 50, color='orange', label=f'Maior valor: {max_artist_song[0]} - {max_artist_song[1]}')

plt.xlabel('Instrumentalness')
plt.ylabel('Numero de músicas')
plt.title('Histograma de Instrumentalness')

description = "Prevê se uma faixa contém vocais ou é puramente instrumental. Varia de 0.0 (vocais presentes) a 1.0 (sem vocais),\n com valores mais altos indicando uma maior probabilidade de música instrumental."
plt.figtext(0.5, -0.05, description, horizontalalignment='center', verticalalignment='center')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# Muitas músicas nesta coluna possuem o valor igual a zero, o que acaba tornando a mediana também igual a zero. Nesse contexto, a mediana não possui muito valor informativo. No entanto, optei por mantê-la por razões de padronização e consistência na análise. Explicando o por que dessa ocorrência, para assim fornecer um contexto compreensível e evitar confusões.

# %% [markdown]
# #### Liveness

# %%
dados_sem_duplicatas['liveness'].describe()
# Out:
# count    6161.000000
# mean        0.180025
# std         0.137777
# min         0.019700
# 25%         0.097100
# 50%         0.124000
# 75%         0.219000
# max         0.977000
# Name: liveness, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['liveness'].idxmin(),
                                     dados_sem_duplicatas['liveness'].idxmax()]]

extremos
# Out:
#                             artist_names                    track_name  \
# 2194  Anitta, Lexa, Luísa Sonza, Rebecca  Combatchy (feat. MC Rebecca)
# 3029                       Gusttavo Lima     Nota de Repúdio - Ao Vivo
#
#                         source    key   mode time_signature  danceability  \
# 2194                 WM Brazil  C#/Db  Major        4 beats         0.826
# 3029  Sony Music Entertainment      E  Major        4 beats         0.811
#
#       energy  speechiness  acousticness  instrumentalness  liveness  valence  \
# 2194   0.730       0.0809         0.383          0.000374    0.0197    0.605
# 3029   0.807       0.1000         0.381          0.000000    0.9770    0.766
#
#       loudness    tempo  duration_ms
# 2194    -3.032  150.134       157600
# 3029    -2.681  115.010       164949

# %%
plt.hist(dados_sem_duplicatas['liveness'], bins=10, color='blue', edgecolor='black')

# Adicionando rótulos
plt.xlabel('Liveness')
plt.ylabel('Frequência')
plt.title('Histograma de Valores')

# Exibindo o histograma
plt.show()

# %%
dados_sem_duplicatas['valence'].describe()
# Out:
# count    6161.000000
# mean        0.492019
# std         0.227305
# min         0.032000
# 25%         0.315000
# 50%         0.488000
# 75%         0.669000
# max         0.982000
# Name: valence, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['valence'].idxmin(),
                                     dados_sem_duplicatas['valence'].idxmax()]]

extremos
# Out:
#                 artist_names                       track_name  \
# 690   Billie Eilish, ROSALÍA  Lo Vas A Olvidar (with ROSALÍA)
# 1473      Earth, Wind & Fire                        September
#
#                source key   mode time_signature  danceability  energy  \
# 690          Columbia   E  Minor        4 beats         0.343   0.243
# 1473  Columbia/Legacy   A  Major        4 beats         0.693   0.911
#
#       speechiness  acousticness  instrumentalness  liveness  valence  \
# 690        0.0777         0.721          0.001980    0.0668    0.032
# 1473       0.0305         0.183          0.000107    0.3000    0.982
#
#       loudness    tempo  duration_ms
# 690    -14.660  135.154       203464
# 1473    -3.691  125.895       216520

# %%
plt.hist(dados_sem_duplicatas['valence'], bins=10, color='blue', edgecolor='black')

# Adicionando rótulos
plt.xlabel('Valence')
plt.ylabel('Frequência')
plt.title('Histograma de Valores')

# Exibindo o histograma
plt.show()

# %%
dados_sem_duplicatas['loudness'].describe()
# Out:
# count    6161.000000
# mean       -6.363845
# std         2.558920
# min       -34.475000
# 25%        -7.578000
# 50%        -5.983000
# 75%        -4.672000
# max         1.509000
# Name: loudness, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['loudness'].idxmin(),
                                     dados_sem_duplicatas['loudness'].idxmax()]]

extremos
# Out:
#          artist_names          track_name                      source    key  \
# 425      XXXTENTACION     The Explanation  Bad Vibes Forever / EMPIRE      C
# 143  Niack, Markim WF  Na Raba Toma Tapão    Niack / Ritmo dos Fluxos  D#/Eb
#
#       mode time_signature  danceability  energy  speechiness  acousticness  \
# 425  Major        5 beats         0.597   0.113       0.9540         0.461
# 143  Minor        4 beats         0.962   0.787       0.0554         0.666
#
#      instrumentalness  liveness  valence  loudness    tempo  duration_ms
# 425          0.000393     0.148    0.313   -34.475   81.311        50748
# 143          0.000057     0.176    0.968     1.509  130.003       165231

# %%
plt.hist(dados_sem_duplicatas['loudness'], bins=15, color='blue', edgecolor='black')

# Adicionando rótulos
plt.xlabel('Loudness')
plt.ylabel('Frequência')
plt.title('Histograma de Valores')

# Exibindo o histograma
plt.show()

# %%
dados_sem_duplicatas['tempo'].describe()
# Out:
# count    6161.000000
# mean      122.176332
# std        29.423222
# min        46.718000
# 25%        98.009000
# 50%       120.056000
# 75%       142.032000
# max       212.117000
# Name: tempo, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['tempo'].idxmin(),
                                     dados_sem_duplicatas['tempo'].idxmax()]]

extremos
# Out:
#                                      artist_names          track_name  \
# 4111  Mykola Dmytrovych Leontovych, John Williams  Carol of the Bells
# 5284                       J Balvin, Jeon, Anitta             Machika
#
#              source    key   mode time_signature  danceability  energy  \
# 4111    Masterworks  G#/Ab  Minor        4 beats         0.418   0.106
# 5284  UMLE - Latino      A  Major        4 beats         0.615   0.833
#
#       speechiness  acousticness  instrumentalness  liveness  valence  \
# 4111       0.0448        0.9940            0.0292     0.179    0.800
# 5284       0.3900        0.0524            0.0000     0.171    0.538
#
#       loudness    tempo  duration_ms
# 4111   -22.507   46.718        85267
# 5284    -3.377  212.117       181733
