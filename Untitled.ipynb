# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %% [markdown]
# ## Analisando colunas e dados

# %%
dados = pd.read_csv('spotify_top_songs_audio_features.csv', sep=',')

dados.head()
# Out:
#                        id                artist_names  \
# 0  000xQL6tZNLJzIrtIgxqSl         ZAYN, PARTYNEXTDOOR
# 1  003eoIwxETJujVWmNFMoZy                Alessia Cara
# 2  003vvx7Niy0yvhvHt4a68B                 The Killers
# 3  00B7TZ0Xawar6NZ00JFomN  Cardi B, Chance the Rapper
# 4  00Blm7zeNqgYLPtW6zg8cj     Post Malone, The Weeknd
#
#                              track_name              source    key   mode  \
# 0  Still Got Time (feat. PARTYNEXTDOOR)   RCA Records Label      G  Major
# 1                         Growing Pains  Def Jam Recordings  C#/Db  Minor
# 2                        Mr. Brightside      Island Records  C#/Db  Major
# 3   Best Life (feat. Chance The Rapper)        Atlantic/KSR      A  Major
# 4       One Right Now (with The Weeknd)    Republic Records  C#/Db  Major
#
#   time_signature  danceability  energy  speechiness  acousticness  \
# 0        4 beats         0.748   0.627       0.0639       0.13100
# 1        4 beats         0.353   0.755       0.7330       0.08220
# 2        4 beats         0.352   0.911       0.0747       0.00121
# 3        4 beats         0.620   0.625       0.5530       0.28700
# 4        4 beats         0.687   0.781       0.0530       0.03610
#
#    instrumentalness  liveness  valence  loudness    tempo  duration_ms  \
# 0               0.0    0.0852    0.524    -6.029  120.963       188491
# 1               0.0    0.3900    0.437    -6.276  191.153       193680
# 2               0.0    0.0995    0.236    -5.230  148.033       222973
# 3               0.0    0.3140    0.665    -7.438  167.911       284856
# 4               0.0    0.0755    0.688    -4.806   97.014       193507
#
#    weeks_on_chart    streams
# 0              17  107527761
# 1               2    9944865
# 2             125  512388123
# 3               2   11985346
# 4              30  301860377

# %%
dados.shape
# Out:
# (6513, 19)

# %%
dados.dtypes
# Out:
# id                   object
# artist_names         object
# track_name           object
# source               object
# key                  object
# mode                 object
# time_signature       object
# danceability        float64
# energy              float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# loudness            float64
# tempo               float64
# duration_ms           int64
# weeks_on_chart        int64
# streams               int64
# dtype: object

# %% [markdown]
# ## Removendo coluna 'id',  pois não achei utilidade para ela por enquanto

# %%
dados = dados.drop('id', axis=1)

# %% [markdown]
# ### Quantidade de aparições de um artista no top200, incluindo participações

# %%
# Divide a string em artistas individuais e conta as ocorrências
artistas = dados['artist_names'].str.split(', ').explode().value_counts().reset_index()

# Renomeia as colunas
artistas.columns = ['Artista', 'QuantidadeAparicoes']

# Imprime o DataFrame resultante
artistas.head(50)
# Out:
#              Artista  QuantidadeAparicoes
# 0              Drake                  229
# 1       Taylor Swift                  203
# 2          Bad Bunny                  159
# 3       Travis Scott                  127
# 4        Post Malone                  111
# 5         Juice WRLD                  110
# 6         The Weeknd                  104
# 7      Ariana Grande                  101
# 8          21 Savage                   97
# 9                BTS                   95
# 10          J Balvin                   90
# 11        Kanye West                   89
# 12        Ed Sheeran                   84
# 13      Lil Uzi Vert                   83
# 14            Future                   81
# 15     Justin Bieber                   78
# 16             Ozuna                   76
# 17            Eminem                   75
# 18          Lil Baby                   67
# 19       Nicki Minaj                   62
# 20          Anuel AA                   62
# 21      Metro Boomin                   61
# 22        Young Thug                   60
# 23      XXXTENTACION                   59
# 24    Kendrick Lamar                   58
# 25               SZA                   57
# 26     Billie Eilish                   57
# 27           KAROL G                   55
# 28            Khalid                   55
# 29             Gunna                   51
# 30           J. Cole                   51
# 31  The Chainsmokers                   50
# 32    Rauw Alejandro                   49
# 33           Cardi B                   48
# 34         Lil Wayne                   47
# 35      Selena Gomez                   46
# 36   Imagine Dragons                   45
# 37          Dua Lipa                   45
# 38      Daddy Yankee                   44
# 39        Peso Pluma                   43
# 40      Shawn Mendes                   42
# 41             Migos                   42
# 42    Camila Cabello                   41
# 43     Ty Dolla $ign                   41
# 44             Logic                   41
# 45          Doja Cat                   40
# 46      Harry Styles                   40
# 47      Lana Del Rey                   39
# 48            Maluma                   39
# 49              Sech                   39

# %% [markdown]
# ### Analisando se foi utilizado algum outro simbolo para dividir dois artitas além da virgula

# %%
padrao = r'[^a-zA-Z0-9\s]'

# Lista para armazenar os artistas que atendem ao critério
artistas_analisar = []

# Iterar sobre as linhas do DataFrame e adicionar os artistas que atendem ao critério à lista
for index, row in artistas.iterrows():
    artista = row['Artista']
    # Verificar se o nome do artista contém caracteres que não são letras nem números
    if re.search(padrao, artista):
        artistas_analisar.append(artista)

# Criar um novo DataFrame com os artistas que atendem ao critério
artistas_analisar = pd.DataFrame({'Artista': artistas_analisar})

artistas_analisar.head(50)
# Out:
#                    Artista
# 0                  J. Cole
# 1            Ty Dolla $ign
# 2                  Beyoncé
# 3               A$AP Rocky
# 4                  ROSALÍA
# 5               Anne-Marie
# 6            Lenny Tavárez
# 7           Anderson .Paak
# 8                   G-Eazy
# 9                       ¥$
# 10           Zion & Lennox
# 11                  Tiësto
# 12                Arcángel
# 13                    P!nk
# 14     Panic! At The Disco
# 15           Michael Bublé
# 16        Marília Mendonça
# 17                Måneskin
# 18                   JAY-Z
# 19             Luísa Sonza
# 20      Axwell /\ Ingrosso
# 21               Zé Felipe
# 22              C. Tangana
# 23     Zé Neto & Cristiano
# 24          Wisin & Yandel
# 25                (G)I-DLE
# 26              Rafa Pabön
# 27                  j-hope
# 28                      MØ
# 29       Israel & Rodolffo
# 30              Ñengo Flow
# 31            Jasiel Nuñez
# 32  Os Barões Da Pisadinha
# 33             Dímelo Flow
# 34                   bbno$
# 35        Hugo & Guilherme
# 36                  H.E.R.
# 37          Jowell & Randy
# 38           Royce Da 5'9"
# 39              João Gomes
# 40          Jorge & Mateus
# 41       Marcynho Sensação
# 42    Tarcísio do Acordeon
# 43      Henrique & Juliano
# 44              Elley Duhé
# 45            Why Don't We
# 46                   Matuê
# 47          Wesley Safadão
# 48         Miksu / Macloud
# 49         Vargas & Lagola

# %% [markdown]
# ### Analisando musicas que mais apareceram

# %%
musicas = dados[['track_name', 'artist_names']].explode('artist_names').groupby(['track_name', 'artist_names']).size().reset_index(name='Quantidade')

# Renomeia as colunas
musicas.columns = ['musica', 'Artista', 'QuantidadeVezes']
musicas = musicas.sort_values(by='QuantidadeVezes', ascending=False)

# Imprime o DataFrame resultante
musicas.head(50)
# Out:
#                                                  musica  \
# 2324                                   Jingle Bell Rock
# 4155                                        Sleigh Ride
# 3052                           My Only Wish (This Year)
# 557                                            Believer
# 4663                                            Thunder
# 4370      Sunflower - Spider-Man: Into the Spider-Verse
# 5035                                  Whatever It Takes
# 5438                         rockstar (feat. 21 Savage)
# 251                            All The Stars (with SZA)
# 2893                                            Mean It
# 4642                                       This Feeling
# 4943                                         Wake Me Up
# 5328                                   fuck, i'm lonely
# 346                              Astronaut In The Ocean
# 3908                                   SPIT IN MY FACE!
# 3396                                  PAINTING PICTURES
# 5021                         What Lovers Do (feat. SZA)
# 3708                                             Ransom
# 5355                                    i'm so tired...
# 4114                                           Sick Boy
# 2728                                       Lucid Dreams
# 1320                                           Dynamite
# 745                                              Butter
# 3005                                 More Than You Know
# 3839                              Roses - Imanbek Remix
# 231                              All Girls Are The Same
# 5069                                    Who Do You Love
# 1791                                         God's Plan
# 2278                                             Issues
# 2018  Homemade Dynamite (Feat. Khalid, Post Malone &...
# 582                                              Better
# 2689                                            Love Me
# 1964                                       Here With Me
# 3814                  Rockin' Around The Christmas Tree
# 2569                          Levitating (feat. DaBaby)
# 1045                                  Cupid - Twin Ver.
# 4700                                         Todo De Ti
# 4594                                   The Night We Met
# 2540                               Lemonade (feat. NAV)
# 4243                                    Sorry Not Sorry
# 1022                                           Criminal
# 952                             Cold Heart - PNAU Remix
# 2662                                      Lose Yourself
# 3298                                      Old Town Road
# 5127                                               Wow.
# 2586                       Life's A Mess (feat. Halsey)
# 2599                                          Lights Up
# 2637              Loco Contigo (feat. J. Balvin & Tyga)
# 4650                                         Those Eyes
# 2529                                Leave The Door Open
#
#                                       Artista  QuantidadeVezes
# 2324                              Bobby Helms                6
# 4155                             The Ronettes                6
# 3052                           Britney Spears                5
# 557                           Imagine Dragons                5
# 4663                          Imagine Dragons                5
# 4370                    Post Malone, Swae Lee                5
# 5035                          Imagine Dragons                5
# 5438                   Post Malone, 21 Savage                4
# 251                       Kendrick Lamar, SZA                4
# 2893                               Lauv, LANY                4
# 4642       The Chainsmokers, Kelsea Ballerini                4
# 4943                                   Avicii                4
# 5328                         Lauv, Anne-Marie                4
# 346                               Masked Wolf                4
# 3908                                 ThxSoMch                4
# 3396                          Superstar Pride                4
# 5021                            Maroon 5, SZA                4
# 3708                                Lil Tecca                4
# 5355                        Lauv, Troye Sivan                4
# 4114                         The Chainsmokers                4
# 2728                               Juice WRLD                4
# 1320                                      BTS                4
# 745                                       BTS                4
# 3005                       Axwell /\ Ingrosso                4
# 3839                       SAINt JHN, Imanbek                4
# 231                                Juice WRLD                4
# 5069    The Chainsmokers, 5 Seconds of Summer                4
# 1791                                    Drake                4
# 2278                           Julia Michaels                4
# 2018          Lorde, Khalid, Post Malone, SZA                3
# 582                                    Khalid                3
# 2689                                Lil Tecca                3
# 1964                                     d4vd                3
# 3814                               Brenda Lee                3
# 2569                         Dua Lipa, DaBaby                3
# 1045                              FIFTY FIFTY                3
# 4700                           Rauw Alejandro                3
# 4594                               Lord Huron                3
# 2540  Internet Money, Gunna, Don Toliver, NAV                3
# 4243                              Demi Lovato                3
# 1022                     NATTI NATASHA, Ozuna                3
# 952                Elton John, Dua Lipa, PNAU                3
# 2662                                   Eminem                3
# 3298                                Lil Nas X                3
# 5127                              Post Malone                3
# 2586                       Juice WRLD, Halsey                3
# 2599                             Harry Styles                3
# 2637                 DJ Snake, J Balvin, Tyga                3
# 4650                                 New West                3
# 2529   Bruno Mars, Anderson .Paak, Silk Sonic                3

# %% [markdown]
# ### Aqui temos um problema quanto as musicas

# %%
ocorrencias = dados[dados['track_name'].str.contains('Jingle Bell Rock')]
ocorrencias
# Out:
#                  artist_names                          track_name  \
# 1331              Bobby Helms                    Jingle Bell Rock
# 3108              Bobby Helms                    Jingle Bell Rock
# 3585              Bobby Helms                    Jingle Bell Rock
# 5382              Bobby Helms                    Jingle Bell Rock
# 5661              Bobby Helms                    Jingle Bell Rock
# 5669  Daryl Hall & John Oates  Jingle Bell Rock - Daryl's Version
# 6450              Bobby Helms                    Jingle Bell Rock
#
#                              source key   mode time_signature  danceability  \
# 1331  Universal Digital Enterprises   D  Major        4 beats         0.741
# 3108                         Geffen   D  Major        4 beats         0.754
# 3585  Universal Digital Enterprises   D  Major        4 beats         0.741
# 5382  Universal Digital Enterprises   D  Major        4 beats         0.729
# 5661           Big Buzz Productions   D  Major        4 beats         0.725
# 5669              Legacy Recordings   D  Major        4 beats         0.666
# 6450                         Geffen   D  Major        4 beats         0.754
#
#       energy  speechiness  acousticness  instrumentalness  liveness  valence  \
# 1331   0.340       0.0446         0.614               0.0    0.0955    0.838
# 3108   0.424       0.0363         0.643               0.0    0.0652    0.806
# 3585   0.326       0.0395         0.918               0.0    0.0658    0.751
# 5382   0.368       0.0435         0.968               0.0    0.0811    0.738
# 5661   0.368       0.0411         0.967               0.0    0.0740    0.700
# 5669   0.841       0.0312         0.613               0.0    0.1130    0.840
# 6450   0.424       0.0363         0.643               0.0    0.0652    0.806
#
#       loudness    tempo  duration_ms  weeks_on_chart    streams
# 1331   -13.421  119.606       129893               6   23307145
# 3108    -8.463  119.705       130973              17   73994656
# 3585   -12.045  120.992       130267               4   15205861
# 5382   -10.765  119.391       133427              43  117756145
# 5661   -10.657  119.438       133407              40   77373767
# 5669    -3.592  128.706       126360              19  156741431
# 6450    -8.463  119.705       130973              36  483558041

# %% [markdown]
# Existem musicas que provavelmente que entraram e sairam do spotify e voltaram novamente em algum momento, covers, musicas com nomes iguais mas artistas diferente e musicas com os mesmos artistas mas colunas com informações sonoras diferentes. Preciso me atentar quando for manipular colunas que musicas repetidas possam atrapalhar os resultados.

# %% [markdown]
# ### Listando gravadoras

# %%
# Divide a string em artistas individuais e conta as ocorrências
source = dados['source'].str.split(', ').explode().value_counts().reset_index()

# Renomeia as colunas
source.columns = ['source', 'QuantidadeAparicoes']

# Imprime o DataFrame resultante
source.head(50)
# Out:
#                                                source  QuantidadeAparicoes
# 0                                            Columbia                  317
# 1                                    Republic Records                  271
# 2                                        Taylor Swift                  178
# 3                                                 LLC                  150
# 4                                      Warner Records                  140
# 5                             Rimas Entertainment LLC                  125
# 6                                    Sony Music Latin                  124
# 7                                        BIGHIT MUSIC                  119
# 8                                    Atlantic Records                  110
# 9                                 Atlantic Records UK                  106
# 10                                  RCA Records Label                   91
# 11                                      UMLE - Latino                   87
# 12                            Generation Now/Atlantic                   76
# 13                                    Polydor Records                   73
# 14             Grade A Productions/Interscope Records                   65
# 15                                          Aftermath                   62
# 16                                                OVO                   58
# 17                                 Def Jam Recordings                   56
# 18                                         WEA Latina                   54
# 19                                     Island Records                   53
# 20                                               Inc.                   52
# 21                         Disruptor Records/Columbia                   51
# 22                        Darkroom/Interscope Records                   50
# 23                                     Slaughter Gang                   45
# 24                                       RBMG/Def Jam                   44
# 25                                               Epic                   44
# 26                           Sony Music Entertainment                   42
# 27                                  300 Entertainment                   41
# 28                                          Som Livre                   40
# 29                                 Interscope Records                   40
# 30                                            Capitol                   40
# 31                                      Parlophone UK                   39
# 32                               Cash Money/Drake LP6                   39
# 33                                                EMI                   38
# 34                                 Universal Music AB                   37
# 35                       Rock The World/IDJ/Kanye LP7                   35
# 36                        Kid Ina Korner / Interscope                   34
# 37                                    Capitol Records                   34
# 38                             Right Hand Music Group                   32
# 39                                    LLC/RCA Records                   32
# 40  Cash Money Records/Young Money Ent./Universal ...                   32
# 41                 Top Dawg Entertainment/RCA Records                   31
# 42                       Kemosabe Records/RCA Records                   31
# 43                         Bad Vibes Forever / EMPIRE                   30
# 44                                   Cactus Jack/Epic                   30
# 45                                    Syco Music/Epic                   30
# 46                         Universal Republic Records                   30
# 47                              Quality Control Music                   28
# 48                                  Olivia Rodrigo PS                   28
# 49                            Victor Victor Worldwide                   28

# %%
key = dados.groupby(['key']).size()
key
# Out:
# key
# A        524
# A#/Bb    465
# B        567
# C        705
# C#/Db    942
# D        524
# D#/Eb    182
# E        424
# F        531
# F#/Gb    501
# G        595
# G#/Ab    553
# dtype: int64

# %%
mode = dados.groupby(['mode']).size()
mode
# Out:
# mode
# Major    3747
# Minor    2766
# dtype: int64

# %%
time_signature = dados.groupby(['time_signature']).size()
time_signature
# Out:
# time_signature
# 1            25
# 3 beats     324
# 4 beats    6057
# 5 beats     107
# dtype: int64

# %% [markdown]
# ### Colunas que devo definir intervalos

# %%
dados.dtypes
# Out:
# artist_names         object
# track_name           object
# source               object
# key                  object
# mode                 object
# time_signature       object
# danceability        float64
# energy              float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# loudness            float64
# tempo               float64
# duration_ms           int64
# weeks_on_chart        int64
# streams               int64
# dtype: object

# %% [markdown]
# ## Removendo duplicadas pois acredito que os resultados das proximas colunas podem ser alterados com essas repetições

# %%
#Removendo colunas sobre semanas no chart e quantidade de streams pois elas n se encaixam para saber se um música é igual ou não
dados_sem_duplicatas = dados.drop(['weeks_on_chart', 'streams'], axis=1)

duplicatas = dados_sem_duplicatas.duplicated()

dados_sem_duplicatas[duplicatas]
# Out:
#                 artist_names                   track_name  \
# 449            Maroon 5, SZA   What Lovers Do (feat. SZA)
# 490               Kanye West                   Praise God
# 710                     Joji     SLOW DANCING IN THE DARK
# 719               Juice WRLD                 Lucid Dreams
# 767                      BTS                     Dynamite
# ...                      ...                          ...
# 6442                  Hozier         Almost (Sweet Music)
# 6450             Bobby Helms             Jingle Bell Rock
# 6477             Post Malone                         Wow.
# 6481       Kygo, OneRepublic                Lose Somebody
# 6485  Juice WRLD, Marshmello  Come & Go (with Marshmello)
#
#                                       source    key   mode time_signature  \
# 449                      Interscope Records*      F  Minor        4 beats
# 490             Rock The World/IDJ/Kanye LP7  C#/Db  Major        4 beats
# 710                           88rising Music  D#/Eb  Major        4 beats
# 719             Juice WRLD Mixtape / ISR P&D  F#/Gb  Minor        4 beats
# 767                             BIGHIT MUSIC  F#/Gb  Minor        4 beats
# ...                                      ...    ...    ...            ...
# 6442           Universal-Island Records Ltd.      G  Major        4 beats
# 6450                                  Geffen      D  Major        4 beats
# 6477                        Republic Records      B  Minor        4 beats
# 6481                                    Kygo  C#/Db  Major        4 beats
# 6485  Grade A Productions/Interscope Records      C  Major        4 beats
#
#       danceability  energy  speechiness  acousticness  instrumentalness  \
# 449          0.799   0.597       0.0611       0.07880          0.000006
# 490          0.798   0.545       0.1680       0.00904          0.000095
# 710          0.515   0.479       0.0261       0.54400          0.005980
# 719          0.511   0.566       0.2000       0.34900          0.000000
# 767          0.746   0.765       0.0993       0.01120          0.000000
# ...            ...     ...          ...           ...               ...
# 6442         0.523   0.687       0.1050       0.02150          0.000003
# 6450         0.754   0.424       0.0363       0.64300          0.000000
# 6477         0.829   0.539       0.2080       0.13600          0.000002
# 6481         0.580   0.586       0.0357       0.34400          0.000000
# 6485         0.625   0.814       0.0657       0.01720          0.000000
#
#       liveness  valence  loudness    tempo  duration_ms
# 449     0.1000    0.419    -5.131  110.001       199849
# 490     0.2580    0.212    -6.466  118.029       226653
# 710     0.1910    0.284    -7.458   88.964       209274
# 719     0.3400    0.218    -7.230   83.903       239836
# 767     0.0936    0.737    -4.410  114.044       199054
# ...        ...      ...       ...      ...          ...
# 6442    0.2030    0.711    -5.601   90.036       217480
# 6450    0.0652    0.806    -8.463  119.705       130973
# 6477    0.1030    0.388    -7.359   99.960       149547
# 6481    0.0755    0.507    -6.883  147.988       199549
# 6485    0.1580    0.535    -5.181  144.991       205485
#
# [352 rows x 16 columns]

# %%
dados_sem_duplicatas = dados_sem_duplicatas.drop_duplicates()

len(dados_sem_duplicatas)
# Out:
# 6161

# %%
dados_sem_duplicatas['danceability'].describe()
# Out:
# count    6161.000000
# mean        0.681581
# std         0.142115
# min         0.150000
# 25%         0.591000
# 50%         0.698000
# 75%         0.786000
# max         0.985000
# Name: danceability, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['danceability'].idxmin(),
                                     dados_sem_duplicatas['danceability'].idxmax()]]

extremos
# Out:
#              artist_names             track_name                source key  \
# 448  Bring Me The Horizon  Can You Feel My Heart     RCA Records Label   E
# 700          MC Rogerinho     Botadinha Saliente  MC Rogerinho Oficial   C
#
#       mode time_signature  danceability  energy  speechiness  acousticness  \
# 448  Minor        5 beats         0.150   0.859       0.0595       0.00201
# 700  Major        4 beats         0.985   0.698       0.0341       0.14200
#
#      instrumentalness  liveness  valence  loudness    tempo  duration_ms
# 448             0.194     0.387    0.354    -2.827  170.527       228147
# 700             0.000     0.321    0.914    -2.531  119.959       158000

# %%
plt.hist(dados_sem_duplicatas['danceability'], bins=10, color='blue', edgecolor='black')

# Adicionando rótulos
plt.xlabel('Danceability')
plt.ylabel('Frequência')
plt.title('Histograma de Valores')

# Exibindo o histograma
plt.show()

# %%
dados_sem_duplicatas['energy'].describe()
# Out:
# count    6161.000000
# mean        0.636363
# std         0.165938
# min         0.021800
# 25%         0.534000
# 50%         0.650000
# 75%         0.760000
# max         0.989000
# Name: energy, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['energy'].idxmin(),
                                     dados_sem_duplicatas['energy'].idxmax()]]

extremos
# Out:
#               artist_names                              track_name  \
# 4834                 Drake                                   Intro
# 2380  Shouse, David Guetta  Love Tonight (David Guetta Remix Edit)
#
#           source    key   mode time_signature  danceability  energy  \
# 4834         OVO      C  Minor        3 beats         0.193  0.0218
# 2380  Hell Beach  A#/Bb  Minor        4 beats         0.621  0.9890
#
#       speechiness  acousticness  instrumentalness  liveness  valence  \
# 4834       0.0389         0.955             0.880     0.117   0.2130
# 2380       0.0434         0.015             0.357     0.184   0.0348
#
#       loudness    tempo  duration_ms
# 4834   -31.160  125.501        36935
# 2380    -4.225  126.002       158095

# %%
plt.hist(dados_sem_duplicatas['energy'], bins=10, color='blue', edgecolor='black')

# Adicionando rótulos
plt.xlabel('Energy')
plt.ylabel('Frequência')
plt.title('Histograma de Valores')

# Exibindo o histograma
plt.show()

# %%
dados_sem_duplicatas['speechiness'].describe()
# Out:
# count    6161.000000
# mean        0.122759
# std         0.114259
# min         0.023200
# 25%         0.044100
# 50%         0.072400
# 75%         0.164000
# max         0.966000
# Name: speechiness, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['speechiness'].idxmin(),
                                     dados_sem_duplicatas['speechiness'].idxmax()]]

extremos
# Out:
#        artist_names   track_name               source    key   mode  \
# 748      Ed Sheeran      Perfect  Atlantic Records UK  G#/Ab  Major
# 419  Paul Rosenberg  Paul - Skit            Aftermath      B  Major
#
#     time_signature  danceability  energy  speechiness  acousticness  \
# 748        3 beats         0.599   0.448       0.0232         0.163
# 419        4 beats         0.636   0.335       0.9660         0.993
#
#      instrumentalness  liveness  valence  loudness   tempo  duration_ms
# 748               0.0     0.106    0.168    -6.312   95.05       263400
# 419               0.0     0.342    0.561   -13.327  161.68        35240

# %%
plt.hist(dados_sem_duplicatas['speechiness'], bins=10, color='blue', edgecolor='black')

# Adicionando rótulos
plt.xlabel('Speechiness')
plt.ylabel('Frequência')
plt.title('Histograma de Valores')

# Exibindo o histograma
plt.show()

# %%
dados_sem_duplicatas['acousticness'].describe()
# Out:
# count    6161.000000
# mean        0.237342
# std         0.245619
# min         0.000008
# 25%         0.044800
# 50%         0.145000
# 75%         0.357000
# max         0.994000
# Name: acousticness, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['acousticness'].idxmin(),
                                     dados_sem_duplicatas['acousticness'].idxmax()]]

extremos
# Out:
#                                      artist_names          track_name  \
# 5512                                      TV Girl         Lovers Rock
# 4111  Mykola Dmytrovych Leontovych, John Williams  Carol of the Bells
#
#            source    key   mode time_signature  danceability  energy  \
# 5512      TV Girl      F  Minor        4 beats         0.559   0.871
# 4111  Masterworks  G#/Ab  Minor        4 beats         0.418   0.106
#
#       speechiness  acousticness  instrumentalness  liveness  valence  \
# 5512       0.0397      0.000008           0.00545     0.096    0.572
# 4111       0.0448      0.994000           0.02920     0.179    0.800
#
#       loudness    tempo  duration_ms
# 5512    -5.338  104.970       213920
# 4111   -22.507   46.718        85267

# %%
plt.hist(dados_sem_duplicatas['acousticness'], bins=10, color='blue', edgecolor='black')

# Adicionando rótulos
plt.xlabel('Acousticness')
plt.ylabel('Frequência')
plt.title('Histograma de Valores')

# Exibindo o histograma
plt.show()

# %%
dados_sem_duplicatas['instrumentalness'].describe()
# Out:
# count    6161.000000
# mean        0.012702
# std         0.075948
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000043
# max         0.953000
# Name: instrumentalness, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['instrumentalness'].idxmin(),
                                     dados_sem_duplicatas['instrumentalness'].idxmax()]]

extremos
# Out:
#              artist_names                            track_name  \
# 0     ZAYN, PARTYNEXTDOOR  Still Got Time (feat. PARTYNEXTDOOR)
# 3577             Kid Cudi                        Beautiful Trip
#
#                  source key   mode time_signature  danceability  energy  \
# 0     RCA Records Label   G  Major        4 beats         0.748   0.627
# 3577   Republic Records   B  Minor        4 beats         0.331   0.513
#
#       speechiness  acousticness  instrumentalness  liveness  valence  \
# 0          0.0639         0.131             0.000    0.0852    0.524
# 3577       0.6320         0.972             0.953    0.8820    0.420
#
#       loudness    tempo  duration_ms
# 0       -6.029  120.963       188491
# 3577   -15.392  133.971        37013

# %%
plt.hist(dados_sem_duplicatas['instrumentalness'], bins=10, color='blue', edgecolor='black')

# Adicionando rótulos
plt.xlabel('Instrumentalness')
plt.ylabel('Frequência')
plt.title('Histograma de Valores')

# Exibindo o histograma
plt.show()

# %%
dados_sem_duplicatas['liveness'].describe()
# Out:
# count    6161.000000
# mean        0.180025
# std         0.137777
# min         0.019700
# 25%         0.097100
# 50%         0.124000
# 75%         0.219000
# max         0.977000
# Name: liveness, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['liveness'].idxmin(),
                                     dados_sem_duplicatas['liveness'].idxmax()]]

extremos
# Out:
#                             artist_names                    track_name  \
# 2194  Anitta, Lexa, Luísa Sonza, Rebecca  Combatchy (feat. MC Rebecca)
# 3029                       Gusttavo Lima     Nota de Repúdio - Ao Vivo
#
#                         source    key   mode time_signature  danceability  \
# 2194                 WM Brazil  C#/Db  Major        4 beats         0.826
# 3029  Sony Music Entertainment      E  Major        4 beats         0.811
#
#       energy  speechiness  acousticness  instrumentalness  liveness  valence  \
# 2194   0.730       0.0809         0.383          0.000374    0.0197    0.605
# 3029   0.807       0.1000         0.381          0.000000    0.9770    0.766
#
#       loudness    tempo  duration_ms
# 2194    -3.032  150.134       157600
# 3029    -2.681  115.010       164949

# %%
plt.hist(dados_sem_duplicatas['liveness'], bins=10, color='blue', edgecolor='black')

# Adicionando rótulos
plt.xlabel('Liveness')
plt.ylabel('Frequência')
plt.title('Histograma de Valores')

# Exibindo o histograma
plt.show()

# %%
dados_sem_duplicatas['valence'].describe()
# Out:
# count    6161.000000
# mean        0.492019
# std         0.227305
# min         0.032000
# 25%         0.315000
# 50%         0.488000
# 75%         0.669000
# max         0.982000
# Name: valence, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['valence'].idxmin(),
                                     dados_sem_duplicatas['valence'].idxmax()]]

extremos
# Out:
#                 artist_names                       track_name  \
# 690   Billie Eilish, ROSALÍA  Lo Vas A Olvidar (with ROSALÍA)
# 1473      Earth, Wind & Fire                        September
#
#                source key   mode time_signature  danceability  energy  \
# 690          Columbia   E  Minor        4 beats         0.343   0.243
# 1473  Columbia/Legacy   A  Major        4 beats         0.693   0.911
#
#       speechiness  acousticness  instrumentalness  liveness  valence  \
# 690        0.0777         0.721          0.001980    0.0668    0.032
# 1473       0.0305         0.183          0.000107    0.3000    0.982
#
#       loudness    tempo  duration_ms
# 690    -14.660  135.154       203464
# 1473    -3.691  125.895       216520

# %%
plt.hist(dados_sem_duplicatas['valence'], bins=10, color='blue', edgecolor='black')

# Adicionando rótulos
plt.xlabel('Valence')
plt.ylabel('Frequência')
plt.title('Histograma de Valores')

# Exibindo o histograma
plt.show()

# %%
dados_sem_duplicatas['loudness'].describe()
# Out:
# count    6161.000000
# mean       -6.363845
# std         2.558920
# min       -34.475000
# 25%        -7.578000
# 50%        -5.983000
# 75%        -4.672000
# max         1.509000
# Name: loudness, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['loudness'].idxmin(),
                                     dados_sem_duplicatas['loudness'].idxmax()]]

extremos
# Out:
#          artist_names          track_name                      source    key  \
# 425      XXXTENTACION     The Explanation  Bad Vibes Forever / EMPIRE      C
# 143  Niack, Markim WF  Na Raba Toma Tapão    Niack / Ritmo dos Fluxos  D#/Eb
#
#       mode time_signature  danceability  energy  speechiness  acousticness  \
# 425  Major        5 beats         0.597   0.113       0.9540         0.461
# 143  Minor        4 beats         0.962   0.787       0.0554         0.666
#
#      instrumentalness  liveness  valence  loudness    tempo  duration_ms
# 425          0.000393     0.148    0.313   -34.475   81.311        50748
# 143          0.000057     0.176    0.968     1.509  130.003       165231

# %%
plt.hist(dados_sem_duplicatas['loudness'], bins=15, color='blue', edgecolor='black')

# Adicionando rótulos
plt.xlabel('Loudness')
plt.ylabel('Frequência')
plt.title('Histograma de Valores')

# Exibindo o histograma
plt.show()

# %%
dados_sem_duplicatas['tempo'].describe()
# Out:
# count    6161.000000
# mean      122.176332
# std        29.423222
# min        46.718000
# 25%        98.009000
# 50%       120.056000
# 75%       142.032000
# max       212.117000
# Name: tempo, dtype: float64

# %%
extremos = dados_sem_duplicatas.loc[[dados_sem_duplicatas['tempo'].idxmin(),
                                     dados_sem_duplicatas['tempo'].idxmax()]]

extremos
# Out:
#                                      artist_names          track_name  \
# 4111  Mykola Dmytrovych Leontovych, John Williams  Carol of the Bells
# 5284                       J Balvin, Jeon, Anitta             Machika
#
#              source    key   mode time_signature  danceability  energy  \
# 4111    Masterworks  G#/Ab  Minor        4 beats         0.418   0.106
# 5284  UMLE - Latino      A  Major        4 beats         0.615   0.833
#
#       speechiness  acousticness  instrumentalness  liveness  valence  \
# 4111       0.0448        0.9940            0.0292     0.179    0.800
# 5284       0.3900        0.0524            0.0000     0.171    0.538
#
#       loudness    tempo  duration_ms
# 4111   -22.507   46.718        85267
# 5284    -3.377  212.117       181733

# %%
plt.hist(dados_sem_duplicatas['tempo'], bins=15, color='blue', edgecolor='black')

# Adicionando rótulos
plt.xlabel('Tempo')
plt.ylabel('Frequência')
plt.title('Histograma de Valores')

# Exibindo o histograma
plt.show()
